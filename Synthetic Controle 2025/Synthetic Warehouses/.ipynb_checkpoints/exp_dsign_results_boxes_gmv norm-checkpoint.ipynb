# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
import pandas as pd

from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,7)

# %%
d = pd.read_csv("grouped_data_full_1.csv")
#d = d[~d["transit_office_id"].isin([130744, 211622, 120762, 507, 206236, 159402, 1733, 207743, 117393, 210127, 117986])]
#d = d[~d["transit_office_id"].isin([218210, 301229])] #большие
d = d[(d["shipment_date"] >= "2023-10-15")]

# %%
d["shipment_date"] = pd.to_datetime(d["shipment_date"])

# %%
actual_routes = pd.read_csv("sums.csv", sep = ";")
actual_routes_list = list(actual_routes["transit_name"])
d["route 1"] = d["transit_wh_name"] + " - " + d["destination_wh_name"]
d = d[d["route 1"].isin(actual_routes_list)]
d
# Out:
#       Unnamed: 0 shipment_date transit_wh_name     destination_wh_name   type  \
# 2              2    2024-01-02     Новосибирск            Электросталь    box
# 5              5    2024-01-02         Обухово  Краснодар (Тихорецкая)    box
# 6              6    2024-01-02         Обухово            Склад Казань    box
# 7              7    2024-01-02         Обухово            Склад Казань  other
# 8              8    2024-01-02      Подольск 4  Краснодар (Тихорецкая)    box
# ...          ...           ...             ...                     ...    ...
# 2774        2774    2024-06-14         Обухово            Склад Казань    box
# 2775        2775    2024-06-14         Обухово            Склад Казань  other
# 2776        2776    2024-06-14      Подольск 4  Краснодар (Тихорецкая)    box
# 2777        2777    2024-06-14      Подольск 4            Невинномысск    box
# 2778        2778    2024-06-14        СЦ Минск                    Тула  other
#
#                gmv  orders                                 route  \
# 2     8.800000e+03       1           Новосибирск -> Электросталь
# 5     1.950000e+04       2     Обухово -> Краснодар (Тихорецкая)
# 6     1.140000e+05       6               Обухово -> Склад Казань
# 7     9.500000e+03       1               Обухово -> Склад Казань
# 8     3.600000e+04       9  Подольск 4 -> Краснодар (Тихорецкая)
# ...            ...     ...                                   ...
# 2774  1.078535e+06      54               Обухово -> Склад Казань
# 2775  1.089650e+05       8               Обухово -> Склад Казань
# 2776  1.756336e+05      15  Подольск 4 -> Краснодар (Тихорецкая)
# 2777  1.300000e+04       2            Подольск 4 -> Невинномысск
# 2778  2.000000e+04       1                      СЦ Минск -> Тула
#
#                                   route 1
# 2              Новосибирск - Электросталь
# 5        Обухово - Краснодар (Тихорецкая)
# 6                  Обухово - Склад Казань
# 7                  Обухово - Склад Казань
# 8     Подольск 4 - Краснодар (Тихорецкая)
# ...                                   ...
# 2774               Обухово - Склад Казань
# 2775               Обухово - Склад Казань
# 2776  Подольск 4 - Краснодар (Тихорецкая)
# 2777            Подольск 4 - Невинномысск
# 2778                      СЦ Минск - Тула
#
# [1928 rows x 9 columns]

# %%
import seaborn as sns

# %%
g = sns.relplot( 
    data=d,
    x="shipment_date", y="gmv", 
    col="route", 
    #hue="is_korob", 
    kind = "line", 
    col_wrap=3, 
    height=3, 
    aspect=2,
)
g.fig.subplots_adjust(top=.8)

# %%
fig = px.line(d, x = "shipment_date", y = "gmv", color = "route")
fig.show()

# %%
# [218210, 301229] большие

# %%
# [206348, 218225, 686] # мини

# %%
d_boxes = d[d["type"] == "box"]

# %%
def fill_nulls(X):
    X = (X.ffill()+X.bfill())/2
    X = X.ffill()
    X = X.bfill()
    return X

# %%
df = d_boxes.pivot(columns = "route", index = "shipment_date", values = "gmv")
df
# Out:
# route          Минск Щомыслицкий -> Коледино  Новосибирск -> Электросталь  \
# shipment_date
# 2024-01-02                               NaN                       8800.0
# 2024-01-03                           12000.0                          NaN
# 2024-01-04                           28000.0                      44000.0
# 2024-01-05                           52000.0                          NaN
# 2024-01-06                           54000.0                      17600.0
# ...                                      ...                          ...
# 2024-06-10                           46825.0                      56760.0
# 2024-06-11                           54750.0                     124784.0
# 2024-06-12                           52500.0                          NaN
# 2024-06-13                           59575.0                          NaN
# 2024-06-14                           14825.0                          NaN
#
# route          Обухово -> Краснодар (Тихорецкая)  Обухово -> Новосибирск  \
# shipment_date
# 2024-01-02                               19500.0                     NaN
# 2024-01-03                               97500.0                     NaN
# 2024-01-04                               78000.0                     NaN
# 2024-01-05                              240500.0                     NaN
# 2024-01-06                              130000.0                     NaN
# ...                                          ...                     ...
# 2024-06-10                              410280.0                349020.0
# 2024-06-11                              672490.0                135000.0
# 2024-06-12                              425425.0                     NaN
# 2024-06-13                              412750.0                     NaN
# 2024-06-14                                   NaN                     NaN
#
# route          Обухово -> СЦ Ижевск  Обухово -> Склад Казань  \
# shipment_date
# 2024-01-02                      NaN                 114000.0
# 2024-01-03                      NaN                  38000.0
# 2024-01-04                      NaN                 294500.0
# 2024-01-05                      NaN                 978500.0
# 2024-01-06                      NaN                 760000.0
# ...                             ...                      ...
# 2024-06-10                      NaN                1840340.0
# 2024-06-11                      NaN                2953740.0
# 2024-06-12                      NaN                2251120.0
# 2024-06-13                   8800.0                2401980.0
# 2024-06-14                   8492.0                1078535.0
#
# route          Подольск 4 -> Краснодар (Тихорецкая)  \
# shipment_date
# 2024-01-02                             36000.000000
# 2024-01-03                            108000.000000
# 2024-01-04                            412000.000000
# 2024-01-05                            548000.000000
# 2024-01-06                            480000.000000
# ...                                             ...
# 2024-06-10                            746995.518298
# 2024-06-11                            871647.250565
# 2024-06-12                            726975.894935
# 2024-06-13                            425556.799849
# 2024-06-14                            175633.568908
#
# route          Подольск 4 -> Невинномысск  СЦ Минск -> Тула  \
# shipment_date
# 2024-01-02                         6000.0               NaN
# 2024-01-03                        12000.0               NaN
# 2024-01-04                        18000.0               NaN
# 2024-01-05                        90000.0               NaN
# 2024-01-06                       138000.0               NaN
# ...                                   ...               ...
# 2024-06-10                        37700.0           52500.0
# 2024-06-11                        98865.0           62025.0
# 2024-06-12                        27625.0           32250.0
# 2024-06-13                            NaN               NaN
# 2024-06-14                        13000.0               NaN
#
# route          СЦ Челябинск 2 -> Электросталь  Тула -> Невинномысск
# shipment_date
# 2024-01-02                                NaN                   NaN
# 2024-01-03                                NaN               12000.0
# 2024-01-04                                NaN                6000.0
# 2024-01-05                                NaN               12000.0
# 2024-01-06                                NaN                6000.0
# ...                                       ...                   ...
# 2024-06-10                                NaN               18000.0
# 2024-06-11                                NaN               30000.0
# 2024-06-12                                NaN                   NaN
# 2024-06-13                                NaN                5400.0
# 2024-06-14                                NaN                   NaN
#
# [165 rows x 11 columns]

# %% [markdown]
# for col in df.columns.values:
#     if sum(df.tail(2)[col].isna()) > 0 or sum(df.head(1)[col].isna()) > 0:
#         del df[col]

# %%
df = fill_nulls(df)
#df

# %%
iter_df = df.copy()
#iter_df

# %%
corr = iter_df.corr()
#corr

# %%
r = "Подольск 4 -> Краснодар (Тихорецкая)"
tmp = corr[[r]].sort_values(by = r, ascending=False)
#tmp = tmp.dropna()
tmp.fillna(0, inplace = True)
tmp
# Out:
# route                                 Подольск 4 -> Краснодар (Тихорецкая)
# route
# Подольск 4 -> Краснодар (Тихорецкая)                              1.000000
# Тула -> Невинномысск                                              0.534616
# Обухово -> Краснодар (Тихорецкая)                                 0.533618
# Обухово -> Склад Казань                                           0.527548
# Подольск 4 -> Невинномысск                                        0.412505
# Минск Щомыслицкий -> Коледино                                     0.355619
# Новосибирск -> Электросталь                                       0.292268
# Обухово -> Новосибирск                                            0.072133
# СЦ Минск -> Тула                                                  0.020901
# Обухово -> СЦ Ижевск                                             -0.226360
# СЦ Челябинск 2 -> Электросталь                                   -0.235587

# %%
controls = tmp[(tmp[r] >= 0.1) & (tmp[r] < 1)].index.values
controls
# Out:
# array(['Тула -> Невинномысск', 'Обухово -> Краснодар (Тихорецкая)',
#        'Обухово -> Склад Казань', 'Подольск 4 -> Невинномысск',
#        'Минск Щомыслицкий -> Коледино', 'Новосибирск -> Электросталь'],
#       dtype=object)

# %%
print(r, controls, sep = "\n")

df_pre = iter_df[iter_df.index <= "2024-05-26"]
df_post = iter_df[iter_df.index > "2024-05-26"]

test_trainsit_id = r
#control__matching_transit_id = 218225

control_transit_ids = [i for i in controls if i != test_trainsit_id]
print(control_transit_ids)

test_pre, test_post = df_pre[[test_trainsit_id]], df_post[[test_trainsit_id]]
test_pre

control_pre, control_post = df_pre[control_transit_ids], df_post[control_transit_ids]
control_pre

y = test_pre
X = control_pre

# Настраиваем веса синтетического города с помощью линейной регрессии
regr = LinearRegression().fit(X, y)

synthetic_control_transit  = regr.predict(pd.concat([control_pre, control_post]))

iter_df["synthetic_control_transit"] = synthetic_control_transit

plot_model = iter_df[[test_trainsit_id, "synthetic_control_transit"]]
  

plt.figure

plt.plot(plot_model.index, plot_model["synthetic_control_transit"], label = "synthetic_control_transit" )
plt.plot(plot_model.index, plot_model[test_trainsit_id], label = f"test_transit {test_trainsit_id}")
#plt.plot(plot_model.index, plot_model[control__matching_transit_id], label = "control_transit_matching (218225)")
plt.title(f"Динамика GMV")
plt.axvspan(xmin = "2024-01-01", xmax = "2024-05-26", color='grey', alpha = 0.1, label = "tarin period") 
plt.axvspan(xmin = "2024-05-26", xmax = "2024-06-20", color='g', alpha = 0.1, label = "test period") 

plt.legend()


plt.show()
# Out:
# Подольск 4 -> Краснодар (Тихорецкая)
# ['Тула -> Невинномысск' 'Обухово -> Краснодар (Тихорецкая)'
#  'Обухово -> Склад Казань' 'Подольск 4 -> Невинномысск'
#  'Минск Щомыслицкий -> Коледино' 'Новосибирск -> Электросталь']
# ['Тула -> Невинномысск', 'Обухово -> Краснодар (Тихорецкая)', 'Обухово -> Склад Казань', 'Подольск 4 -> Невинномысск', 'Минск Щомыслицкий -> Коледино', 'Новосибирск -> Электросталь']

# %%
r = "Подольск 4 -> Краснодар (Тихорецкая)"
iter_df = df.copy()
#iter_df = iter_df.dropna()

corr = iter_df.corr()
tmp = corr[[r]].sort_values(by = r, ascending=False)
controls = tmp[(tmp[r] >= 0.1) & (tmp[r] < 1)].index.values
print(r, controls, sep = "\n")

window = 7
for col in iter_df.columns.values:
    iter_df[col] = iter_df[col].rolling(window).mean()


iter_df = iter_df[window:]
iter_df = fill_nulls(iter_df)

df_pre = iter_df[iter_df.index <= "2024-05-26"]
df_post = iter_df[iter_df.index > "2024-05-26"]

test_trainsit_id = r
#control__matching_transit_id = 218225

control_transit_ids = [i for i in controls if i != test_trainsit_id]

test_pre, test_post = df_pre[[test_trainsit_id]], df_post[[test_trainsit_id]]
test_pre

control_pre, control_post = df_pre[control_transit_ids], df_post[control_transit_ids]
control_pre

y = test_pre
X = control_pre

# Настраиваем веса синтетического города с помощью линейной регрессии
regr = LinearRegression().fit(X, y)

synthetic_control_transit  = regr.predict(pd.concat([control_pre, control_post]))

iter_df["synthetic_control_transit"] = synthetic_control_transit

plot_model = iter_df[[test_trainsit_id, "synthetic_control_transit"]]
  

plt.figure

plt.plot(plot_model.index, plot_model["synthetic_control_transit"], label = "synthetic_control_transit" )
plt.plot(plot_model.index, plot_model[test_trainsit_id], label = f"test_transit {test_trainsit_id}")
#plt.plot(plot_model.index, plot_model[control__matching_transit_id], label = "control_transit_matching (218225)")
plt.title(f"Динамика GMV: сглаженные ряды (ma 7)")
plt.axvspan(xmin = "2024-01-01", xmax = "2024-05-26", color='grey', alpha = 0.1, label = "tarin period") 
plt.axvspan(xmin = "2024-05-26", xmax = "2024-06-20", color='g', alpha = 0.1, label = "test period") 

plt.legend()


plt.show()
# Out:
# Подольск 4 -> Краснодар (Тихорецкая)
# ['Тула -> Невинномысск' 'Обухово -> Краснодар (Тихорецкая)'
#  'Обухово -> Склад Казань' 'Подольск 4 -> Невинномысск'
#  'Минск Щомыслицкий -> Коледино' 'Новосибирск -> Электросталь']
