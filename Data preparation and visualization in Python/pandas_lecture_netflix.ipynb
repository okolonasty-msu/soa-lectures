# %%
import pandas as pd
import json

# %%
data_url = 'https://raw.githubusercontent.com/okolonasty-msu/soa-lectures/main/Data%20preparation%20and%20visualization%20in%20Python/imdb_movies_shows.csv'

# %%
data = pd.read_csv(data_url)
data.head()
# Out:
#                                  title   type  release_year age_certification  \
# 0  Five Came Back: The Reference Films   SHOW          1945             TV-MA
# 1                          Taxi Driver  MOVIE          1976                 R
# 2      Monty Python and the Holy Grail  MOVIE          1975                PG
# 3                        Life of Brian  MOVIE          1979                 R
# 4                         The Exorcist  MOVIE          1973                 R
#
#    runtime                 genres production_countries  seasons    imdb_id  \
# 0       48      ['documentation']               ['US']      1.0        NaN
# 1      113     ['crime', 'drama']               ['US']      NaN  tt0075314
# 2       91  ['comedy', 'fantasy']               ['GB']      NaN  tt0071853
# 3       94             ['comedy']               ['GB']      NaN  tt0079470
# 4      133             ['horror']               ['US']      NaN  tt0070047
#
#    imdb_score  imdb_votes
# 0         NaN         NaN
# 1         8.3    795222.0
# 2         8.2    530877.0
# 3         8.0    392419.0
# 4         8.1    391942.0

# %%
data.shape
# Out:
# (5806, 11)

# %%
# работает только для численных переменных
data.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes
# count   5806.000000  5806.000000  2047.000000  5283.000000  5.267000e+03
# mean    2016.013434    77.643989     2.165608     6.533447  2.340719e+04
# std        7.324883    39.474160     2.636207     1.160932  8.713432e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2015.000000    44.000000     1.000000     5.800000  5.210000e+02
# 50%     2018.000000    84.000000     1.000000     6.600000  2.279000e+03
# 75%     2020.000000   105.000000     2.000000     7.400000  1.014400e+04
# max     2022.000000   251.000000    42.000000     9.600000  2.268288e+06

# %%
data.dtypes
# Out:
# title                    object
# type                     object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 5805 non-null   object
#  1   type                  5806 non-null   object
#  2   release_year          5806 non-null   int64
#  3   age_certification     3196 non-null   object
#  4   runtime               5806 non-null   int64
#  5   genres                5806 non-null   object
#  6   production_countries  5806 non-null   object
#  7   seasons               2047 non-null   float64
#  8   imdb_id               5362 non-null   object
#  9   imdb_score            5283 non-null   float64
#  10  imdb_votes            5267 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 499.1+ KB

# %%
data.head(3)
# Out:
#                                  title   type  release_year age_certification  \
# 0  Five Came Back: The Reference Films   SHOW          1945             TV-MA
# 1                          Taxi Driver  MOVIE          1976                 R
# 2      Monty Python and the Holy Grail  MOVIE          1975                PG
#
#    runtime                 genres production_countries  seasons    imdb_id  \
# 0       48      ['documentation']               ['US']      1.0        NaN
# 1      113     ['crime', 'drama']               ['US']      NaN  tt0075314
# 2       91  ['comedy', 'fantasy']               ['GB']      NaN  tt0071853
#
#    imdb_score  imdb_votes
# 0         NaN         NaN
# 1         8.3    795222.0
# 2         8.2    530877.0

# %%
data.tail(3)
# Out:
#                                    title   type  release_year  \
# 5803                               Clash  MOVIE          2021
# 5804                      Shadow Parties  MOVIE          2021
# 5805  Mighty Little Bheem: Kite Festival   SHOW          2021
#
#      age_certification  runtime                             genres  \
# 5803               NaN       88                ['family', 'drama']
# 5804               NaN      116             ['action', 'thriller']
# 5805               NaN        0  ['family', 'comedy', 'animation']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes
# 5803         ['NG', 'CA']      NaN  tt14620732         6.5        32.0
# 5804                   []      NaN  tt10168094         6.2         9.0
# 5805                   []      1.0  tt13711094         8.8        16.0

# %% [markdown]
# ## Работа со столбцами

# %%
data['title']
# Out:
# 0       Five Came Back: The Reference Films
# 1                               Taxi Driver
# 2           Monty Python and the Holy Grail
# 3                             Life of Brian
# 4                              The Exorcist
#                        ...
# 5801                              Fine Wine
# 5802                         Edis Starlight
# 5803                                  Clash
# 5804                         Shadow Parties
# 5805     Mighty Little Bheem: Kite Festival
# Name: title, Length: 5806, dtype: object

# %%
data.title
# Out:
# 0       Five Came Back: The Reference Films
# 1                               Taxi Driver
# 2           Monty Python and the Holy Grail
# 3                             Life of Brian
# 4                              The Exorcist
#                        ...
# 5801                              Fine Wine
# 5802                         Edis Starlight
# 5803                                  Clash
# 5804                         Shadow Parties
# 5805     Mighty Little Bheem: Kite Festival
# Name: title, Length: 5806, dtype: object

# %%
data['release_year'].describe()
# Out:
# count    5806.000000
# mean     2016.013434
# std         7.324883
# min      1945.000000
# 25%      2015.000000
# 50%      2018.000000
# 75%      2020.000000
# max      2022.000000
# Name: release_year, dtype: float64

# %%
type(data['release_year'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Обращение к нескольким столбцам

# %%
data.index
# Out:
# RangeIndex(start=0, stop=5806, step=1)

# %%
data.columns
# Out:
# Index(['title', 'type', 'release_year', 'age_certification', 'runtime',
#        'genres', 'production_countries', 'seasons', 'imdb_id', 'imdb_score',
#        'imdb_votes'],
#       dtype='object')

# %%
data.columns.values
# Out:
# array(['title', 'type', 'release_year', 'age_certification', 'runtime',
#        'genres', 'production_countries', 'seasons', 'imdb_id',
#        'imdb_score', 'imdb_votes'], dtype=object)

# %%
data[   ['runtime', 'title', 'type', 'release_year', 'age_certification']    ]
# Out:
#       runtime                                title   type  release_year  \
# 0          48  Five Came Back: The Reference Films   SHOW          1945
# 1         113                          Taxi Driver  MOVIE          1976
# 2          91      Monty Python and the Holy Grail  MOVIE          1975
# 3          94                        Life of Brian  MOVIE          1979
# 4         133                         The Exorcist  MOVIE          1973
# ...       ...                                  ...    ...           ...
# 5801      100                            Fine Wine  MOVIE          2021
# 5802       74                       Edis Starlight  MOVIE          2021
# 5803       88                                Clash  MOVIE          2021
# 5804      116                       Shadow Parties  MOVIE          2021
# 5805        0   Mighty Little Bheem: Kite Festival   SHOW          2021
#
#      age_certification
# 0                TV-MA
# 1                    R
# 2                   PG
# 3                    R
# 4                    R
# ...                ...
# 5801               NaN
# 5802               NaN
# 5803               NaN
# 5804               NaN
# 5805               NaN
#
# [5806 rows x 5 columns]

# %%
data.iloc[0]
# Out:
# title                   Five Came Back: The Reference Films
# type                                                   SHOW
# release_year                                           1945
# age_certification                                     TV-MA
# runtime                                                  48
# genres                                    ['documentation']
# production_countries                                 ['US']
# seasons                                                 1.0
# imdb_id                                                 NaN
# imdb_score                                              NaN
# imdb_votes                                              NaN
# Name: 0, dtype: object

# %%
data.iloc[[1]]
# Out:
#          title   type  release_year age_certification  runtime  \
# 1  Taxi Driver  MOVIE          1976                 R      113
#
#                genres production_countries  seasons    imdb_id  imdb_score  \
# 1  ['crime', 'drama']               ['US']      NaN  tt0075314         8.3
#
#    imdb_votes
# 1    795222.0

# %%
type(data.iloc[[0]]) == type(data.iloc[0])
# Out:
# False

# %%
print(type(data.iloc[0]), type(data.iloc[[0]]), sep = '\n')
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data.iloc[-500:-356]
# Out:
#                                    title   type  release_year  \
# 5306                         A Week Away  MOVIE          2021
# 5307                     Crazy About Her  MOVIE          2021
# 5308                          Below Zero  MOVIE          2021
# 5309                     Light the Night   SHOW          2021
# 5310                          800 Meters   SHOW          2022
# ...                                  ...    ...           ...
# 5445               The Girl on the Train  MOVIE          2021
# 5446                 A Tale Dark & Grimm   SHOW          2021
# 5447                                 Ray   SHOW          2021
# 5448                    Shyam Singha Roy  MOVIE          2021
# 5449  Phil Wang: Philly Philly Wang Wang  MOVIE          2021
#
#      age_certification  runtime  \
# 5306               NaN       94
# 5307               NaN      102
# 5308               NaN      106
# 5309             TV-MA       57
# 5310             TV-MA       52
# ...                ...      ...
# 5445               NaN      128
# 5446             TV-Y7       31
# 5447             TV-MA       59
# 5448               NaN      157
# 5449               NaN       63
#
#                                                  genres production_countries  \
# 5306                     ['drama', 'family', 'romance']               ['US']
# 5307                              ['comedy', 'romance']               ['ES']
# 5308  ['action', 'crime', 'horror', 'thriller', 'dra...               ['ES']
# 5309                     ['drama', 'thriller', 'crime']               ['TW']
# 5310                         ['documentation', 'crime']               ['ES']
# ...                                                 ...                  ...
# 5445                     ['drama', 'thriller', 'crime']               ['IN']
# 5446  ['comedy', 'family', 'fantasy', 'animation', '...         ['ES', 'US']
# 5447                     ['drama', 'thriller', 'crime']               ['IN']
# 5448         ['drama', 'romance', 'horror', 'thriller']               ['IN']
# 5449                                         ['comedy']               ['GB']
#
#       seasons     imdb_id  imdb_score  imdb_votes
# 5306      NaN  tt11388278         5.7      4465.0
# 5307      NaN  tt11698630         6.6      5435.0
# 5308      NaN   tt9845564         6.2     18840.0
# 5309      3.0  tt15808044         7.4       968.0
# 5310      1.0  tt13323170         6.9       459.0
# ...       ...         ...         ...         ...
# 5445      NaN   tt8907992         4.4     14348.0
# 5446      1.0   tt2386826         7.3      1193.0
# 5447      1.0  tt14160660         7.2      8668.0
# 5448      NaN  tt13349716         7.9     10903.0
# 5449      NaN  tt15091640         6.0       561.0
#
# [144 rows x 11 columns]

# %%
data.iloc[0:3]
# Out:
#                                  title   type  release_year age_certification  \
# 0  Five Came Back: The Reference Films   SHOW          1945             TV-MA
# 1                          Taxi Driver  MOVIE          1976                 R
# 2      Monty Python and the Holy Grail  MOVIE          1975                PG
#
#    runtime                 genres production_countries  seasons    imdb_id  \
# 0       48      ['documentation']               ['US']      1.0        NaN
# 1      113     ['crime', 'drama']               ['US']      NaN  tt0075314
# 2       91  ['comedy', 'fantasy']               ['GB']      NaN  tt0071853
#
#    imdb_score  imdb_votes
# 0         NaN         NaN
# 1         8.3    795222.0
# 2         8.2    530877.0

# %%
type(data.iloc[0:3])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Вспоминаем срезы

# %%
data.iloc[::2]
# Out:
#                                     title   type  release_year  \
# 0     Five Came Back: The Reference Films   SHOW          1945
# 2         Monty Python and the Holy Grail  MOVIE          1975
# 4                            The Exorcist  MOVIE          1973
# 6                             Dirty Harry  MOVIE          1971
# 8                         The Blue Lagoon  MOVIE          1980
# ...                                   ...    ...           ...
# 5796                          The Big Day   SHOW          2021
# 5798                        Time to Dance  MOVIE          2021
# 5800          Momshies! Your Soul is Mine  MOVIE          2021
# 5802                       Edis Starlight  MOVIE          2021
# 5804                       Shadow Parties  MOVIE          2021
#
#      age_certification  runtime                           genres  \
# 0                TV-MA       48                ['documentation']
# 2                   PG       91            ['comedy', 'fantasy']
# 4                    R      133                       ['horror']
# 6                    R      102  ['thriller', 'crime', 'action']
# 8                    R      104             ['romance', 'drama']
# ...                ...      ...                              ...
# 5796             TV-MA       45           ['reality', 'romance']
# 5798               NaN      107             ['drama', 'romance']
# 5800               NaN      108                       ['comedy']
# 5802               NaN       74       ['music', 'documentation']
# 5804               NaN      116           ['action', 'thriller']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes
# 0                  ['US']      1.0         NaN         NaN         NaN
# 2                  ['GB']      NaN   tt0071853         8.2    530877.0
# 4                  ['US']      NaN   tt0070047         8.1    391942.0
# 6                  ['US']      NaN   tt0066999         7.7    153463.0
# 8                  ['US']      NaN   tt0080453         5.8     69053.0
# ...                   ...      ...         ...         ...         ...
# 5796               ['US']      2.0  tt13887518         4.6       327.0
# 5798               ['IN']      NaN   tt8622232         2.2       950.0
# 5800               ['PH']      NaN  tt14412240         5.8        26.0
# 5802                   []      NaN         NaN         NaN         NaN
# 5804                   []      NaN  tt10168094         6.2         9.0
#
# [2903 rows x 11 columns]

# %% [markdown]
# ### Задание: вытащить из массива data последние 10 строк двумя способами

# %% [markdown]
# # Превращаю строки в объекты питона c помощью apply

# %%
data['genres'].apply(lambda x: x[0])
# Out:
# 0       [
# 1       [
# 2       [
# 3       [
# 4       [
#        ..
# 5801    [
# 5802    [
# 5803    [
# 5804    [
# 5805    [
# Name: genres, Length: 5806, dtype: object

# %%
data['genres'] = data['genres'].apply(lambda x: x.replace("'", "\""))

# %%
data['genres_list'] = data['genres'].apply(json.loads)

# %%
type(data['genres'][0])
# Out:
# str

# %%
data['production_countries'] = data['production_countries'].str.replace("'", "\"")

# %%
data['production_countries_list'] = data['production_countries'].apply(json.loads)

# %%
type(data['production_countries_list'][0])
# Out:
# list

# %% [markdown]
# # Вытаскивание данных по условиям

# %% [markdown]
# data [условие]

# %%
data['release_year'] == 2022
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5801    False
# 5802    False
# 5803    False
# 5804    False
# 5805    False
# Name: release_year, Length: 5806, dtype: bool

# %%
data[(data['release_year'] == 2022) & (data['genres'].str.contains('documentation'))]
# Out:
#                                                   title   type  release_year  \
# 4834                           Our Great National Parks   SHOW          2022
# 4842  Conversations with a Killer: The John Wayne Ga...   SHOW          2022
# 4844  White Hot: The Rise & Fall of Abercrombie & Fitch  MOVIE          2022
# 4851                 Bad Vegan: Fame. Fraud. Fugitives.   SHOW          2022
# 4858                                          Hard Cell   SHOW          2022
# 4862               Jimmy Savile: A British Horror Story   SHOW          2022
# 4864   The Mystery of Marilyn Monroe: The Unheard Tapes  MOVIE          2022
# 4876                        Meltdown: Three Mile Island   SHOW          2022
# 4890                                    Return to Space  MOVIE          2022
# 4896                            The Andy Warhol Diaries   SHOW          2022
# 4908                                The Tinder Swindler  MOVIE          2022
# 4913                                Worst Roommate Ever   SHOW          2022
# 4924                  Downfall: The Case Against Boeing  MOVIE          2022
# 4939                                          jeen-yuhs   SHOW          2022
# 4946                     Hold Your Breath: The Ice Dive  MOVIE          2022
# 4955                                        Wild Babies   SHOW          2022
# 4957         Trust No One: The Hunt for the Crypto King  MOVIE          2022
# 4964     The Puppet Master: Hunting the Ultimate Conman   SHOW          2022
# 4976                         The Principles of Pleasure   SHOW          2022
# 4991                                A Farewell to Ozark  MOVIE          2022
# 5002                      Taylor Tomlinson: Look at You  MOVIE          2022
# 5172                          Neymar: The Perfect Chaos   SHOW          2022
# 5196                  Jeff Foxworthy: The Good Old Days  MOVIE          2022
# 5221                     Senzo: Murder of a Soccer Star   SHOW          2022
# 5310                                         800 Meters   SHOW          2022
# 5330                Michela Giraud: The Truth, I Swear!  MOVIE          2022
# 5345                       Johnny Hallyday: Beyond Rock   SHOW          2022
# 5346                  Surviving Paradise: A Family Tale  MOVIE          2022
# 5359          Broken Idol: The Undoing of Diomedes Díaz  MOVIE          2022
# 5416                 Midnight Asia: Eat · Dance · Dream   SHOW          2022
# 5434                                                UFO  MOVIE          2022
# 5511                            Mike Epps: Indiana Mike  MOVIE          2022
# 5528                                                11M  MOVIE          2022
# 5555                                Race: Bubba Wallace   SHOW          2022
# 5585  Hei$t: The Great Robbery of Brazil's Central Bank   SHOW          2022
# 5631                Behind the Scenes With Jane Campion  MOVIE          2022
# 5684                    Whindersson Nunes: My Own Show!  MOVIE          2022
# 5694                     Celeb Five: Behind the Curtain  MOVIE          2022
#
#      age_certification  runtime  \
# 4834               NaN       52
# 4842             TV-MA       61
# 4844                 R       88
# 4851             TV-MA       52
# 4858             TV-MA       26
# 4862             TV-MA       85
# 4864                 R      101
# 4876             TV-14       44
# 4890               NaN      128
# 4896             TV-MA       66
# 4908               NaN      114
# 4913             TV-MA       47
# 4924                 R       89
# 4939             TV-MA       93
# 4946               NaN       40
# 4955               NaN       30
# 4957                 R       90
# 4964             TV-MA       42
# 4976             TV-MA       51
# 4991               NaN       30
# 5002               NaN       60
# 5172             TV-MA       55
# 5196               NaN       60
# 5221               NaN       40
# 5310             TV-MA       52
# 5330               NaN       60
# 5345             TV-14       35
# 5346               NaN       78
# 5359                 R      102
# 5416             TV-MA       37
# 5434               NaN      109
# 5511               NaN       58
# 5528               NaN       92
# 5555             TV-MA       47
# 5585             TV-14       61
# 5631               NaN       17
# 5684               NaN       63
# 5694               NaN       55
#
#                                                genres production_countries  \
# 4834                                ['documentation']               ["US"]
# 4842                       ['crime', 'documentation']               ["US"]
# 4844                                ['documentation']               ["US"]
# 4851                       ['crime', 'documentation']               ["US"]
# 4858             ['comedy', 'documentation', 'sport']         ["US", "GB"]
# 4862                       ['crime', 'documentation']               ["GB"]
# 4864                                ['documentation']               ["US"]
# 4876                     ['documentation', 'history']               ["US"]
# 4890                                ['documentation']               ["US"]
# 4896                                ['documentation']               ["US"]
# 4908                       ['crime', 'documentation']               ["GB"]
# 4913  ['crime', 'documentation', 'drama', 'thriller']               ["US"]
# 4924                                ['documentation']               ["US"]
# 4939                       ['documentation', 'music']               ["US"]
# 4946                                ['documentation']                   []
# 4955                                ['documentation']               ["GB"]
# 4957                       ['crime', 'documentation']               ["GB"]
# 4964                       ['crime', 'documentation']               ["GB"]
# 4976                                ['documentation']               ["US"]
# 4991                                ['documentation']               ["US"]
# 5002                      ['comedy', 'documentation']                   []
# 5172                       ['documentation', 'sport']         ["BR", "US"]
# 5196                      ['comedy', 'documentation']                   []
# 5221                       ['crime', 'documentation']         ["ZA", "US"]
# 5310                       ['documentation', 'crime']               ["ES"]
# 5330                      ['comedy', 'documentation']               ["IT"]
# 5345                       ['documentation', 'music']               ["US"]
# 5346                                ['documentation']         ["US", "GB"]
# 5359                       ['documentation', 'crime']               ["CO"]
# 5416                                ['documentation']               ["SG"]
# 5434            ['drama', 'romance', 'documentation']               ["TR"]
# 5511                      ['comedy', 'documentation']                   []
# 5528                                ['documentation']               ["ES"]
# 5555                       ['documentation', 'sport']               ["US"]
# 5585                       ['documentation', 'crime']               ["BR"]
# 5631                                ['documentation']               ["US"]
# 5684                      ['comedy', 'documentation']               ["BR"]
# 5694                      ['comedy', 'documentation']               ["KR"]
#
#       seasons     imdb_id  imdb_score  imdb_votes production_countries_list
# 4834      1.0  tt18750552         NaN         NaN                      [US]
# 4842      1.0  tt18970124         7.2      3984.0                      [US]
# 4844      NaN  tt19034522         5.6      1184.0                      [US]
# 4851      1.0  tt18260538         5.8      2062.0                      [US]
# 4858      1.0  tt14959710         6.1       618.0                  [US, GB]
# 4862      1.0  tt18970454         6.7      4711.0                      [GB]
# 4864      NaN  tt19034332         6.2      2233.0                      [US]
# 4876      1.0  tt19757508         7.0       958.0                      [US]
# 4890      NaN  tt18555320         7.3      3270.0                      [US]
# 4896      1.0  tt18082212         7.7      1496.0                      [US]
# 4908      NaN  tt14992922         7.2     57606.0                      [GB]
# 4913      1.0   tt8323702         8.1         8.0                      [US]
# 4924      NaN  tt11893274         7.4      9428.0                      [US]
# 4939      1.0  tt14599438         8.1      7269.0                      [US]
# 4946      NaN  tt19373274         NaN         NaN                        []
# 4955      1.0  tt19398016         NaN         NaN                      [GB]
# 4957      NaN  tt15479902         6.3      3850.0                      [GB]
# 4964      1.0  tt15479704         7.0      5224.0                      [GB]
# 4976      1.0  tt18299058         4.7        64.0                      [US]
# 4991      NaN         NaN         NaN         NaN                      [US]
# 5002      NaN  tt18096250         7.3      1707.0                        []
# 5172      1.0  tt16428640         6.6      2907.0                  [BR, US]
# 5196      NaN  tt18314220         6.1       374.0                        []
# 5221      1.0  tt18954258         NaN         NaN                  [ZA, US]
# 5310      1.0  tt13323170         6.9       459.0                      [ES]
# 5330      NaN  tt18396984         5.5        54.0                      [IT]
# 5345      1.0  tt18274456         7.0        94.0                      [US]
# 5346      NaN  tt18059108         7.5       551.0                  [US, GB]
# 5359      NaN  tt18750180         6.1       144.0                      [CO]
# 5416      1.0  tt16583602         6.6       474.0                      [SG]
# 5434      NaN  tt14369286         4.8       728.0                      [TR]
# 5511      NaN  tt18314226         NaN         NaN                        []
# 5528      NaN   tt6275154         7.0       796.0                      [ES]
# 5555      1.0  tt14513646         5.9       402.0                      [US]
# 5585      1.0  tt18274172         6.3       193.0                      [BR]
# 5631      NaN         NaN         NaN         NaN                      [US]
# 5684      NaN  tt17887288         7.1       186.0                      [BR]
# 5694      NaN  tt18570468         NaN         NaN                      [KR]

# %% [markdown]
# data [условие] [столбцы]

# %%
data[(data['release_year'] == 2022) & (data['genres'].str.contains('documentation'))][['runtime', 'imdb_score']]
# Out:
#       runtime  imdb_score
# 4834       52         NaN
# 4842       61         7.2
# 4844       88         5.6
# 4851       52         5.8
# 4858       26         6.1
# 4862       85         6.7
# 4864      101         6.2
# 4876       44         7.0
# 4890      128         7.3
# 4896       66         7.7
# 4908      114         7.2
# 4913       47         8.1
# 4924       89         7.4
# 4939       93         8.1
# 4946       40         NaN
# 4955       30         NaN
# 4957       90         6.3
# 4964       42         7.0
# 4976       51         4.7
# 4991       30         NaN
# 5002       60         7.3
# 5172       55         6.6
# 5196       60         6.1
# 5221       40         NaN
# 5310       52         6.9
# 5330       60         5.5
# 5345       35         7.0
# 5346       78         7.5
# 5359      102         6.1
# 5416       37         6.6
# 5434      109         4.8
# 5511       58         NaN
# 5528       92         7.0
# 5555       47         5.9
# 5585       61         6.3
# 5631       17         NaN
# 5684       63         7.1
# 5694       55         NaN

# %%
data[data['release_year'].isin([2000,2023])]
# Out:
#                            title   type  release_year age_certification  \
# 105                     Survivor   SHOW          2000             TV-PG
# 116                Gilmore Girls   SHOW          2000             TV-14
# 134                     InuYasha   SHOW          2000             TV-14
# 139                  The Patriot  MOVIE          2000                 R
# 140                    Road Trip  MOVIE          2000                 R
# 145             The Replacements  MOVIE          2000             PG-13
# 154                   Hollow Man  MOVIE          2000                 R
# 167              Under Suspicion  MOVIE          2000                 R
# 173                  Girlfriends   SHOW          2000             TV-PG
# 205                       Okupas   SHOW          2000             TV-MA
# 209  Phir Bhi Dil Hai Hindustani  MOVIE          2000             PG-13
# 220     Before the Flying Circus  MOVIE          2000               NaN
# 238                         Fiza  MOVIE          2000               NaN
#
#      runtime                                             genres  \
# 105       48                                        ['reality']
# 116       46                                ['comedy', 'drama']
# 134       25  ['action', 'comedy', 'scifi', 'animation', 'dr...
# 139      165              ['drama', 'action', 'history', 'war']
# 140       93                                         ['comedy']
# 145      118                                ['comedy', 'sport']
# 154      112          ['scifi', 'action', 'horror', 'thriller']
# 167      110         ['thriller', 'crime', 'drama', 'european']
# 173       21                                ['comedy', 'drama']
# 205       40                                 ['crime', 'drama']
# 209      160                     ['comedy', 'romance', 'drama']
# 220       55                        ['comedy', 'documentation']
# 238      170            ['drama', 'romance', 'action', 'crime']
#
#     production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 105               ["US"]     42.0  tt0239195         7.4     24368.0
# 116               ["US"]      8.0  tt0238784         8.2    119054.0
# 134               ["JP"]      9.0  tt0290223         7.9     15823.0
# 139         ["DE", "US"]      NaN  tt0187393         7.2    270231.0
# 140               ["US"]      NaN  tt0215129         6.5    167670.0
# 145               ["US"]      NaN  tt0191397         6.6     64087.0
# 154         ["DE", "US"]      NaN  tt0164052         5.8    130099.0
# 167               ["US"]      NaN  tt0164212         6.5     25432.0
# 173               ["US"]      8.0  tt0247102         7.2      4482.0
# 205               ["AR"]      1.0  tt0289649         9.0      2326.0
# 209               ["IN"]      NaN  tt0222270         6.1      7556.0
# 220               ["GB"]      NaN  tt9230920         7.3       161.0
# 238               ["IN"]      NaN  tt0248012         6.0      4168.0
#
#     production_countries_list
# 105                      [US]
# 116                      [US]
# 134                      [JP]
# 139                  [DE, US]
# 140                      [US]
# 145                      [US]
# 154                  [DE, US]
# 167                      [US]
# 173                      [US]
# 205                      [AR]
# 209                      [IN]
# 220                      [GB]
# 238                      [IN]

# %%
data[ data['release_year'].isin(range(2000,2023))]
# Out:
#                                    title   type  release_year  \
# 105                             Survivor   SHOW          2000
# 116                        Gilmore Girls   SHOW          2000
# 134                             InuYasha   SHOW          2000
# 139                          The Patriot  MOVIE          2000
# 140                            Road Trip  MOVIE          2000
# ...                                  ...    ...           ...
# 5801                           Fine Wine  MOVIE          2021
# 5802                      Edis Starlight  MOVIE          2021
# 5803                               Clash  MOVIE          2021
# 5804                      Shadow Parties  MOVIE          2021
# 5805  Mighty Little Bheem: Kite Festival   SHOW          2021
#
#      age_certification  runtime  \
# 105              TV-PG       48
# 116              TV-14       46
# 134              TV-14       25
# 139                  R      165
# 140                  R       93
# ...                ...      ...
# 5801               NaN      100
# 5802               NaN       74
# 5803               NaN       88
# 5804               NaN      116
# 5805               NaN        0
#
#                                                  genres production_countries  \
# 105                                         ['reality']               ["US"]
# 116                                 ['comedy', 'drama']               ["US"]
# 134   ['action', 'comedy', 'scifi', 'animation', 'dr...               ["JP"]
# 139               ['drama', 'action', 'history', 'war']         ["DE", "US"]
# 140                                          ['comedy']               ["US"]
# ...                                                 ...                  ...
# 5801                               ['romance', 'drama']               ["NG"]
# 5802                         ['music', 'documentation']                   []
# 5803                                ['family', 'drama']         ["NG", "CA"]
# 5804                             ['action', 'thriller']                   []
# 5805                  ['family', 'comedy', 'animation']                   []
#
#       seasons     imdb_id  imdb_score  imdb_votes production_countries_list
# 105      42.0   tt0239195         7.4     24368.0                      [US]
# 116       8.0   tt0238784         8.2    119054.0                      [US]
# 134       9.0   tt0290223         7.9     15823.0                      [JP]
# 139       NaN   tt0187393         7.2    270231.0                  [DE, US]
# 140       NaN   tt0215129         6.5    167670.0                      [US]
# ...       ...         ...         ...         ...                       ...
# 5801      NaN  tt13857480         6.9        39.0                      [NG]
# 5802      NaN         NaN         NaN         NaN                        []
# 5803      NaN  tt14620732         6.5        32.0                  [NG, CA]
# 5804      NaN  tt10168094         6.2         9.0                        []
# 5805      1.0  tt13711094         8.8        16.0                        []
#
# [5576 rows x 12 columns]

# %%
data[ data['release_year'].isin(range(2000,2024))]
# Out:
#                                    title   type  release_year  \
# 105                             Survivor   SHOW          2000
# 116                        Gilmore Girls   SHOW          2000
# 134                             InuYasha   SHOW          2000
# 139                          The Patriot  MOVIE          2000
# 140                            Road Trip  MOVIE          2000
# ...                                  ...    ...           ...
# 5801                           Fine Wine  MOVIE          2021
# 5802                      Edis Starlight  MOVIE          2021
# 5803                               Clash  MOVIE          2021
# 5804                      Shadow Parties  MOVIE          2021
# 5805  Mighty Little Bheem: Kite Festival   SHOW          2021
#
#      age_certification  runtime  \
# 105              TV-PG       48
# 116              TV-14       46
# 134              TV-14       25
# 139                  R      165
# 140                  R       93
# ...                ...      ...
# 5801               NaN      100
# 5802               NaN       74
# 5803               NaN       88
# 5804               NaN      116
# 5805               NaN        0
#
#                                                  genres production_countries  \
# 105                                         ['reality']               ["US"]
# 116                                 ['comedy', 'drama']               ["US"]
# 134   ['action', 'comedy', 'scifi', 'animation', 'dr...               ["JP"]
# 139               ['drama', 'action', 'history', 'war']         ["DE", "US"]
# 140                                          ['comedy']               ["US"]
# ...                                                 ...                  ...
# 5801                               ['romance', 'drama']               ["NG"]
# 5802                         ['music', 'documentation']                   []
# 5803                                ['family', 'drama']         ["NG", "CA"]
# 5804                             ['action', 'thriller']                   []
# 5805                  ['family', 'comedy', 'animation']                   []
#
#       seasons     imdb_id  imdb_score  imdb_votes production_countries_list
# 105      42.0   tt0239195         7.4     24368.0                      [US]
# 116       8.0   tt0238784         8.2    119054.0                      [US]
# 134       9.0   tt0290223         7.9     15823.0                      [JP]
# 139       NaN   tt0187393         7.2    270231.0                  [DE, US]
# 140       NaN   tt0215129         6.5    167670.0                      [US]
# ...       ...         ...         ...         ...                       ...
# 5801      NaN  tt13857480         6.9        39.0                      [NG]
# 5802      NaN         NaN         NaN         NaN                        []
# 5803      NaN  tt14620732         6.5        32.0                  [NG, CA]
# 5804      NaN  tt10168094         6.2         9.0                        []
# 5805      1.0  tt13711094         8.8        16.0                        []
#
# [5576 rows x 12 columns]

# %%
data[ ~data['release_year'].isin(range(2000,2024))]
# Out:
#                                             title   type  release_year  \
# 0             Five Came Back: The Reference Films   SHOW          1945
# 1                                     Taxi Driver  MOVIE          1976
# 2                 Monty Python and the Holy Grail  MOVIE          1975
# 3                                   Life of Brian  MOVIE          1979
# 4                                    The Exorcist  MOVIE          1973
# ..                                            ...    ...           ...
# 237                                      Dushmani  MOVIE          1995
# 239                                 Hello Brother  MOVIE          1999
# 240  Have You Ever Seen Fireflies? - Theatre Play  MOVIE          1999
# 241                                       Shikari  MOVIE          1991
# 242                                 One Last Shot  MOVIE          1998
#
#     age_certification  runtime                                      genres  \
# 0               TV-MA       48                           ["documentation"]
# 1                   R      113                          ["crime", "drama"]
# 2                  PG       91                       ["comedy", "fantasy"]
# 3                   R       94                                  ["comedy"]
# 4                   R      133                                  ["horror"]
# ..                ...      ...                                         ...
# 237               NaN      156              ["romance", "action", "drama"]
# 239               NaN      131  ["romance", "action", "comedy", "fantasy"]
# 240               NaN      118                         ["drama", "comedy"]
# 241               NaN      162                         ["drama", "action"]
# 242               NaN       30                                          []
#
#     production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0                 ["US"]      1.0        NaN         NaN         NaN
# 1                 ["US"]      NaN  tt0075314         8.3    795222.0
# 2                 ["GB"]      NaN  tt0071853         8.2    530877.0
# 3                 ["GB"]      NaN  tt0079470         8.0    392419.0
# 4                 ["US"]      NaN  tt0070047         8.1    391942.0
# ..                   ...      ...        ...         ...         ...
# 237               ["IN"]      NaN  tt0112916         5.0       248.0
# 239               ["IN"]      NaN  tt0233856         4.6      4230.0
# 240               ["TR"]      NaN        NaN         NaN         NaN
# 241         ["IN", "SU"]      NaN  tt0170416         5.9        66.0
# 242                   []      NaN        NaN         NaN         NaN
#
#                             genres_list production_countries_list
# 0                       [documentation]                      [US]
# 1                        [crime, drama]                      [US]
# 2                     [comedy, fantasy]                      [GB]
# 3                              [comedy]                      [GB]
# 4                              [horror]                      [US]
# ..                                  ...                       ...
# 237            [romance, action, drama]                      [IN]
# 239  [romance, action, comedy, fantasy]                      [IN]
# 240                     [drama, comedy]                      [TR]
# 241                     [drama, action]                  [IN, SU]
# 242                                  []                        []
#
# [230 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data['type'], color = 'red', label = 'type')
plt.show()

# %%
plt.hist(data['runtime'], color = 'blue', histtype = 'step')
plt.show()

# %%
plt.hist(data['runtime'], bins = 50)
plt.show()

# %%
plt.hist(data[data['type'] == 'SHOW']['runtime'], bins = 50)
plt.show()

# %%
plt.hist(data[data['type'] == 'MOVIE']['runtime'], bins = 50)
plt.show()

# %%
plt.scatter(data['runtime'], data['imdb_score'])
plt.show()
